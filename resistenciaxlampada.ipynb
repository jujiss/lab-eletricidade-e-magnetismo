# %% [markdown]
# <a href="https://colab.research.google.com/github/jujiss/lab-eletricidade-e-magnetismo/blob/main/resistenciaxlampada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [0.00, 0.31, 0.65, 1.04,1.32, 1.55, 1.91, 2.20, 2.79, 3.36, 4.05, 4.87, 5.24, 5.77, 6.04]
y = [0.00, 0.69, 1.40, 2.23, 2.84, 3.33, 4.10, 4.73, 6.00, 7.19, 8.70, 10.45, 11.24, 12.38, 12.96]

plt.plot(x, y, marker='o', color='deeppink', label='Resistência')
plt.xlabel('Tensão (V)', fontsize=12)
plt.ylabel('Corrente (mA)', fontsize=12)


z = [0.21, 0.51, 0.82, 1.39, 2.11, 2.53, 3.38, 3.88, 4.24, 4.59, 5.31, 5.58, 5.88, 6.15, 6.62]
w = [13.7, 18.1, 21.9, 27.9, 34.9, 38.1, 44.6, 48.2, 50.6, 52.9, 57.3, 58.9, 60.6, 62.1, 64.7]

plt.plot(z, w, marker='o', color='dodgerblue', label='Lâmpada')
plt.xlabel('Tensão (V)', fontsize=12)
plt.ylabel('Corrente (mA)', fontsize=12)


plt.legend()
plt.show(True)
